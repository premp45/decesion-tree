# %% [markdown]
# <a href="https://colab.research.google.com/github/premp45/decesion-tree/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris


iris_data = load_iris()

# Separate features (X) and target (y)
X = iris_data.data
y = iris_data.target


print("Iris dataset loaded successfully.")
print(f"Shape of features (X): {X.shape}")
print(f"Shape of target (y): {y.shape}")
# Out:
# Iris dataset loaded successfully.
# Shape of features (X): (150, 4)
# Shape of target (y): (150,)

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


print("Dataset split into training and testing sets successfully.")
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Dataset split into training and testing sets successfully.
# Shape of X_train: (105, 4)
# Shape of X_test: (45, 4)
# Shape of y_train: (105,)
# Shape of y_test: (45,)

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the Decision Tree Classifier with a specified random_state for reproducibility
dtc = DecisionTreeClassifier(random_state=42)


dtc.fit(X_train, y_train)


print("Decision Tree Classifier trained successfully.")
# Out:
# Decision Tree Classifier trained successfully.

# %%
from sklearn.metrics import classification_report, accuracy_score


y_pred = dtc.predict(X_test)


print("Classification Report:")
print(classification_report(y_test, y_pred))


accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score: {accuracy:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# Accuracy Score: 1.00

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt


plt.figure(figsize=(20, 15))

# Plot the decision tree
plot_tree(dtc,
          filled=True,
          feature_names=iris_data.feature_names,
          class_names=iris_data.target_names)


plt.title('Decision Tree Visualization')


plt.show()
